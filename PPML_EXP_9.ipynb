# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan-327/IML-LAB/blob/main/PPML_EXP_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
    return a+b
print(add(5,6))


def pro(a,b):
    print(a*b)
pro(4,7)


def d(n ,a):
    print(n,a)
d(a=20,n='aryan')

def s(n ,c):
    print(n,c)
s(c='py',n='aryan')


def greet(n='aryan'):
    print(n)
greet()

# %%
def bill(a=100):
    print("bill:",a)
bill(500)
bill()

def total(*n):
    print(sum(n))
total(10,20,30)

# %%
def emp(**details):
    for k , v in details.items():
        print(k,':',v)
emp(name = 'aryan',id =7,dept = 'it')

# %%
#min to hr + min
min = int (input('time in min: '))
hr = min //60
r=min%60
print('time in hr and min  is : ',hr,' hr + ',r,'min')

# %%
#m to km
m = float(input('distance in m: '))
km = m/1000
print('distance in km is : ',km,'km')

# %%
#number sys
x = int(input('enter decimal no: '))
print(x)
print('binary equivalent: ', bin(x))

print('octal equivalent: ', oct(x))

print('hexa decimal equivalent: ', hex(x))
